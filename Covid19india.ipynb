# %%
import pandas as pd
import numpy as np

# %%
#Get Data From API's

df1 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data1.csv')
df2 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data2.csv')
df3 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data3.csv')
df4 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data4.csv')
df5 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data5.csv')
df6 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data6.csv')
df7 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data7.csv')
df8 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data8.csv')
df9 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data9.csv')
df10 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data10.csv')
df11 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data11.csv')
df12 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data12.csv')
df13 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data13.csv')
df14 = pd.read_csv('http://api.covid19india.org/csv/latest/raw_data14.csv')

# %%
df1.head()
# Out:
#    Patient Number State Patient Number Date Announced  Estimated Onset Date  \
# 0             1.0             KL-TS-P1     30/01/2020                   NaN
# 1             2.0             KL-AL-P1     02/02/2020                   NaN
# 2             3.0             KL-KS-P1     03/02/2020                   NaN
# 3             4.0                DL-P1     02/03/2020                   NaN
# 4             5.0                TS-P1     02/03/2020                   NaN
#
#   Age Bracket Gender             Detected City Detected District  \
# 0          20      F                  Thrissur          Thrissur
# 1         NaN    NaN                 Alappuzha         Alappuzha
# 2         NaN    NaN                 Kasaragod         Kasaragod
# 3          45      M  East Delhi (Mayur Vihar)        East Delhi
# 4          24      M                 Hyderabad         Hyderabad
#
#   Detected State State code  ...  \
# 0         Kerala         KL  ...
# 1         Kerala         KL  ...
# 2         Kerala         KL  ...
# 3          Delhi         DL  ...
# 4      Telangana         TG  ...
#
#                                                Notes  \
# 0                               Travelled from Wuhan
# 1                               Travelled from Wuhan
# 2                               Travelled from Wuhan
# 3                      Travelled from Austria, Italy
# 4  Travelled from Dubai to Bangalore on 20th Feb,...
#
#   Contracted from which Patient (Suspected) Nationality Type of transmission  \
# 0                                       NaN       India             Imported
# 1                                       NaN       India             Imported
# 2                                       NaN       India             Imported
# 3                                       NaN       India             Imported
# 4                                       NaN       India             Imported
#
#   Status Change Date                                           Source_1  \
# 0         14/02/2020  https://twitter.com/vijayanpinarayi/status/122...
# 1         14/02/2020  https://www.indiatoday.in/india/story/kerala-r...
# 2         14/02/2020  https://www.indiatoday.in/india/story/kerala-n...
# 3         15/03/2020  https://www.indiatoday.in/india/story/not-a-ja...
# 4         02/03/2020  https://www.deccanherald.com/national/south/qu...
#
#                                             Source_2  \
# 0  https://weather.com/en-IN/india/news/news/2020...
# 1  https://weather.com/en-IN/india/news/news/2020...
# 2  https://twitter.com/ANI/status/122422148580539...
# 3  https://economictimes.indiatimes.com/news/poli...
# 4  https://www.indiatoday.in/india/story/coronavi...
#
#                                             Source_3  \
# 0                                                NaN
# 1                                                NaN
# 2  https://weather.com/en-IN/india/news/news/2020...
# 3                                                NaN
# 4  https://www.thehindu.com/news/national/coronav...
#
#                                  Backup Notes Num Cases
# 0                          Student from Wuhan         1
# 1                          Student from Wuhan         1
# 2                          Student from Wuhan         1
# 3         Travel history to Italy and Austria         1
# 4  Travel history to Dubai, Singapore contact         1
#
# [5 rows x 21 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17364 entries, 0 to 17363
# Data columns (total 21 columns):
# Patient Number                               17306 non-null float64
# State Patient Number                         2457 non-null object
# Date Announced                               17364 non-null object
# Estimated Onset Date                         0 non-null float64
# Age Bracket                                  1670 non-null object
# Gender                                       3746 non-null object
# Detected City                                2166 non-null object
# Detected District                            14978 non-null object
# Detected State                               17363 non-null object
# State code                                   17363 non-null object
# Current Status                               17364 non-null object
# Notes                                        16046 non-null object
# Contracted from which Patient (Suspected)    1537 non-null object
# Nationality                                  1554 non-null object
# Type of transmission                         2951 non-null object
# Status Change Date                           17195 non-null object
# Source_1                                     17075 non-null object
# Source_2                                     3396 non-null object
# Source_3                                     445 non-null object
# Backup Notes                                 361 non-null object
# Num Cases                                    17364 non-null int64
# dtypes: float64(2), int64(1), object(18)
# memory usage: 2.8+ MB

# %%
df1.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Num Cases'],
#       dtype='object')

# %%
df8.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
#Match the column name
df1 = df1.rename(columns={'Num cases':'Num Cases'})
df2 = df2.rename(columns={'Num cases':'Num Cases'})

# %%
df2.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Num Cases'],
#       dtype='object')

# %%
#Retain All Necessary Columns

df1 = df1.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df2 = df2.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df3 = df3.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df4 = df4.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df5 = df5.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df6 = df6.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df7 = df7.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df8 = df8.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df9 = df9.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df10 = df10.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df11 = df11.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df12 = df12.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]
df13 = df13.loc[:, ['Num Cases','Date Announced','Age Bracket', 'Gender', 'Detected City','Detected District', 'Detected State', 'Current Status']]

# %%
#Combine All into One DataFrame

df = df1.append([df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13])
df
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0            1.0     30/01/2020          20      F                  Thrissur
# 1            1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2            1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3            1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4            1.0     02/03/2020          24      M                 Hyderabad
# 5            1.0     03/03/2020          69      M                    Jaipur
# 6            1.0     04/03/2020          55    NaN                  Gurugram
# 7            1.0     04/03/2020          55    NaN                  Gurugram
# 8            1.0     04/03/2020          55    NaN                  Gurugram
# 9            1.0     04/03/2020          55    NaN                  Gurugram
# 10           1.0     04/03/2020          55    NaN                  Gurugram
# 11           1.0     04/03/2020          55    NaN                  Gurugram
# 12           1.0     04/03/2020          55    NaN                  Gurugram
# 13           1.0     04/03/2020          55    NaN                  Gurugram
# 14           1.0     04/03/2020          55    NaN                  Gurugram
# 15           1.0     04/03/2020          55    NaN                  Gurugram
# 16           1.0     04/03/2020          55    NaN                  Gurugram
# 17           1.0     04/03/2020          55    NaN                  Gurugram
# 18           1.0     04/03/2020          55    NaN                  Gurugram
# 19           1.0     04/03/2020          55    NaN                  Gurugram
# 20           1.0     04/03/2020          70      F                    Jaipur
# 21           1.0     04/03/2020         NaN      M                      Agra
# 22           1.0     04/03/2020         NaN      F                      Agra
# 23           1.0     04/03/2020          45      F                      Agra
# 24           1.0     04/03/2020         NaN      M                      Agra
# 25           1.0     04/03/2020          16      M                      Agra
# 26           1.0     04/03/2020         NaN    NaN                      Agra
# 27           1.0     04/03/2020         NaN    NaN                       NaN
# 28           1.0     05/03/2020          27      M                 Janakpuri
# 29           1.0     05/03/2020          59      M                 Ghaziabad
# ...          ...            ...         ...    ...                       ...
# 24217        5.0     21/08/2020         NaN    NaN                       NaN
# 24218        4.0     21/08/2020         NaN    NaN                       NaN
# 24219        4.0     21/08/2020         NaN    NaN                       NaN
# 24220        3.0     21/08/2020         NaN    NaN                       NaN
# 24221        3.0     21/08/2020         NaN    NaN                       NaN
# 24222        2.0     21/08/2020         NaN    NaN                       NaN
# 24223        2.0     21/08/2020         NaN    NaN                       NaN
# 24224        2.0     21/08/2020         NaN    NaN                       NaN
# 24225       16.0     21/08/2020         NaN    NaN                       NaN
# 24226        4.0     21/08/2020         NaN    NaN                       NaN
# 24227        4.0     21/08/2020         NaN    NaN                       NaN
# 24228        3.0     21/08/2020         NaN    NaN                       NaN
# 24229        2.0     21/08/2020         NaN    NaN                       NaN
# 24230        2.0     21/08/2020         NaN    NaN                       NaN
# 24231        1.0     21/08/2020         NaN    NaN                       NaN
# 24232       -2.0     21/08/2020         NaN    NaN                       NaN
# 24233        2.0     21/08/2020         NaN    NaN                       NaN
# 24234       -5.0     21/08/2020         NaN    NaN                       NaN
# 24235        5.0     21/08/2020         NaN    NaN                       NaN
# 24236       30.0     21/08/2020         NaN    NaN                       NaN
# 24237       13.0     21/08/2020         NaN    NaN                       NaN
# 24238        7.0     21/08/2020         NaN    NaN                       NaN
# 24239        1.0     21/08/2020         NaN    NaN                       NaN
# 24240        8.0     21/08/2020         NaN    NaN                       NaN
# 24241        6.0     21/08/2020         NaN    NaN                       NaN
# 24242        1.0     21/08/2020         NaN    NaN                       NaN
# 24243        1.0     21/08/2020         NaN    NaN                       NaN
# 24244        1.0     21/08/2020         NaN    NaN                       NaN
# 24245     2476.0     21/08/2020         NaN    NaN                       NaN
# 24246        NaN            NaN         NaN    NaN                       NaN
#
#          Detected District     Detected State Current Status
# 0                 Thrissur             Kerala      Recovered
# 1                Alappuzha             Kerala      Recovered
# 2                Kasaragod             Kerala      Recovered
# 3               East Delhi              Delhi      Recovered
# 4                Hyderabad          Telangana      Recovered
# 5                 Italians          Rajasthan      Recovered
# 6                 Italians            Haryana      Recovered
# 7                 Italians            Haryana      Recovered
# 8                 Italians            Haryana      Recovered
# 9                 Italians            Haryana      Recovered
# 10                Italians            Haryana      Recovered
# 11                Italians            Haryana      Recovered
# 12                Italians            Haryana      Recovered
# 13                Italians            Haryana      Recovered
# 14                Italians            Haryana      Recovered
# 15                Italians            Haryana      Recovered
# 16                Italians            Haryana      Recovered
# 17                Italians            Haryana      Recovered
# 18                Italians            Haryana   Hospitalized
# 19                Italians            Haryana   Hospitalized
# 20                Italians          Rajasthan      Recovered
# 21                    Agra      Uttar Pradesh   Hospitalized
# 22                    Agra      Uttar Pradesh      Recovered
# 23                    Agra      Uttar Pradesh      Recovered
# 24                    Agra      Uttar Pradesh      Recovered
# 25                    Agra      Uttar Pradesh      Recovered
# 26                    Agra      Uttar Pradesh   Hospitalized
# 27                    Agra      Uttar Pradesh   Hospitalized
# 28        South West Delhi              Delhi   Hospitalized
# 29               Ghaziabad      Uttar Pradesh      Recovered
# ...                    ...                ...            ...
# 24217           East Siang  Arunachal Pradesh   Hospitalized
# 24218          East Kameng  Arunachal Pradesh   Hospitalized
# 24219               Namsai  Arunachal Pradesh   Hospitalized
# 24220           West Siang  Arunachal Pradesh   Hospitalized
# 24221               Tawang  Arunachal Pradesh   Hospitalized
# 24222           Papum Pare  Arunachal Pradesh   Hospitalized
# 24223          Lower Siang  Arunachal Pradesh   Hospitalized
# 24224        Pakke Kessang  Arunachal Pradesh   Hospitalized
# 24225          East Kameng  Arunachal Pradesh      Recovered
# 24226          West Kameng  Arunachal Pradesh      Recovered
# 24227          Lower Siang  Arunachal Pradesh      Recovered
# 24228           Papum Pare  Arunachal Pradesh      Recovered
# 24229                Tirap  Arunachal Pradesh      Recovered
# 24230  Lower Dibang Valley  Arunachal Pradesh      Recovered
# 24231          Upper Siang  Arunachal Pradesh      Recovered
# 24232                  NaN          Meghalaya   Hospitalized
# 24233     East Khasi Hills          Meghalaya   Hospitalized
# 24234                  NaN          Meghalaya      Recovered
# 24235     East Khasi Hills          Meghalaya      Recovered
# 24236               Raipur       Chhattisgarh   Hospitalized
# 24237              Raigarh       Chhattisgarh   Hospitalized
# 24238       Janjgir Champa       Chhattisgarh   Hospitalized
# 24239             Dhamtari       Chhattisgarh   Hospitalized
# 24240               Raipur       Chhattisgarh      Recovered
# 24241                 Durg       Chhattisgarh      Recovered
# 24242                Balod       Chhattisgarh      Recovered
# 24243             Bametara       Chhattisgarh      Recovered
# 24244          Other State       Chhattisgarh      Recovered
# 24245                  NaN              Assam      Recovered
# 24246                  NaN                NaN            NaN
#
# [271480 rows x 8 columns]

# %%
DATE = df['Date Announced'].str.split('/', expand=True)
DATE.columns=['Day','Month','Year']

# %%
df.insert(7, 'Day',DATE.Day)

# %%
df.insert(8, 'Month',DATE.Month)

# %%
df.insert(9, 'Year',DATE.Year)

# %%
df
# Out:
#        Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0            1.0     30/01/2020          20      F                  Thrissur
# 1            1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2            1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3            1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4            1.0     02/03/2020          24      M                 Hyderabad
# 5            1.0     03/03/2020          69      M                    Jaipur
# 6            1.0     04/03/2020          55    NaN                  Gurugram
# 7            1.0     04/03/2020          55    NaN                  Gurugram
# 8            1.0     04/03/2020          55    NaN                  Gurugram
# 9            1.0     04/03/2020          55    NaN                  Gurugram
# 10           1.0     04/03/2020          55    NaN                  Gurugram
# 11           1.0     04/03/2020          55    NaN                  Gurugram
# 12           1.0     04/03/2020          55    NaN                  Gurugram
# 13           1.0     04/03/2020          55    NaN                  Gurugram
# 14           1.0     04/03/2020          55    NaN                  Gurugram
# 15           1.0     04/03/2020          55    NaN                  Gurugram
# 16           1.0     04/03/2020          55    NaN                  Gurugram
# 17           1.0     04/03/2020          55    NaN                  Gurugram
# 18           1.0     04/03/2020          55    NaN                  Gurugram
# 19           1.0     04/03/2020          55    NaN                  Gurugram
# 20           1.0     04/03/2020          70      F                    Jaipur
# 21           1.0     04/03/2020         NaN      M                      Agra
# 22           1.0     04/03/2020         NaN      F                      Agra
# 23           1.0     04/03/2020          45      F                      Agra
# 24           1.0     04/03/2020         NaN      M                      Agra
# 25           1.0     04/03/2020          16      M                      Agra
# 26           1.0     04/03/2020         NaN    NaN                      Agra
# 27           1.0     04/03/2020         NaN    NaN                       NaN
# 28           1.0     05/03/2020          27      M                 Janakpuri
# 29           1.0     05/03/2020          59      M                 Ghaziabad
# ...          ...            ...         ...    ...                       ...
# 24217        5.0     21/08/2020         NaN    NaN                       NaN
# 24218        4.0     21/08/2020         NaN    NaN                       NaN
# 24219        4.0     21/08/2020         NaN    NaN                       NaN
# 24220        3.0     21/08/2020         NaN    NaN                       NaN
# 24221        3.0     21/08/2020         NaN    NaN                       NaN
# 24222        2.0     21/08/2020         NaN    NaN                       NaN
# 24223        2.0     21/08/2020         NaN    NaN                       NaN
# 24224        2.0     21/08/2020         NaN    NaN                       NaN
# 24225       16.0     21/08/2020         NaN    NaN                       NaN
# 24226        4.0     21/08/2020         NaN    NaN                       NaN
# 24227        4.0     21/08/2020         NaN    NaN                       NaN
# 24228        3.0     21/08/2020         NaN    NaN                       NaN
# 24229        2.0     21/08/2020         NaN    NaN                       NaN
# 24230        2.0     21/08/2020         NaN    NaN                       NaN
# 24231        1.0     21/08/2020         NaN    NaN                       NaN
# 24232       -2.0     21/08/2020         NaN    NaN                       NaN
# 24233        2.0     21/08/2020         NaN    NaN                       NaN
# 24234       -5.0     21/08/2020         NaN    NaN                       NaN
# 24235        5.0     21/08/2020         NaN    NaN                       NaN
# 24236       30.0     21/08/2020         NaN    NaN                       NaN
# 24237       13.0     21/08/2020         NaN    NaN                       NaN
# 24238        7.0     21/08/2020         NaN    NaN                       NaN
# 24239        1.0     21/08/2020         NaN    NaN                       NaN
# 24240        8.0     21/08/2020         NaN    NaN                       NaN
# 24241        6.0     21/08/2020         NaN    NaN                       NaN
# 24242        1.0     21/08/2020         NaN    NaN                       NaN
# 24243        1.0     21/08/2020         NaN    NaN                       NaN
# 24244        1.0     21/08/2020         NaN    NaN                       NaN
# 24245     2476.0     21/08/2020         NaN    NaN                       NaN
# 24246        NaN            NaN         NaN    NaN                       NaN
#
#          Detected District     Detected State  Day Month  Year Current Status
# 0                 Thrissur             Kerala   30    01  2020      Recovered
# 1                Alappuzha             Kerala   02    02  2020      Recovered
# 2                Kasaragod             Kerala   03    02  2020      Recovered
# 3               East Delhi              Delhi   02    03  2020      Recovered
# 4                Hyderabad          Telangana   02    03  2020      Recovered
# 5                 Italians          Rajasthan   03    03  2020      Recovered
# 6                 Italians            Haryana   04    03  2020      Recovered
# 7                 Italians            Haryana   04    03  2020      Recovered
# 8                 Italians            Haryana   04    03  2020      Recovered
# 9                 Italians            Haryana   04    03  2020      Recovered
# 10                Italians            Haryana   04    03  2020      Recovered
# 11                Italians            Haryana   04    03  2020      Recovered
# 12                Italians            Haryana   04    03  2020      Recovered
# 13                Italians            Haryana   04    03  2020      Recovered
# 14                Italians            Haryana   04    03  2020      Recovered
# 15                Italians            Haryana   04    03  2020      Recovered
# 16                Italians            Haryana   04    03  2020      Recovered
# 17                Italians            Haryana   04    03  2020      Recovered
# 18                Italians            Haryana   04    03  2020   Hospitalized
# 19                Italians            Haryana   04    03  2020   Hospitalized
# 20                Italians          Rajasthan   04    03  2020      Recovered
# 21                    Agra      Uttar Pradesh   04    03  2020   Hospitalized
# 22                    Agra      Uttar Pradesh   04    03  2020      Recovered
# 23                    Agra      Uttar Pradesh   04    03  2020      Recovered
# 24                    Agra      Uttar Pradesh   04    03  2020      Recovered
# 25                    Agra      Uttar Pradesh   04    03  2020      Recovered
# 26                    Agra      Uttar Pradesh   04    03  2020   Hospitalized
# 27                    Agra      Uttar Pradesh   04    03  2020   Hospitalized
# 28        South West Delhi              Delhi   05    03  2020   Hospitalized
# 29               Ghaziabad      Uttar Pradesh   05    03  2020      Recovered
# ...                    ...                ...  ...   ...   ...            ...
# 24217           East Siang  Arunachal Pradesh   21    08  2020   Hospitalized
# 24218          East Kameng  Arunachal Pradesh   21    08  2020   Hospitalized
# 24219               Namsai  Arunachal Pradesh   21    08  2020   Hospitalized
# 24220           West Siang  Arunachal Pradesh   21    08  2020   Hospitalized
# 24221               Tawang  Arunachal Pradesh   21    08  2020   Hospitalized
# 24222           Papum Pare  Arunachal Pradesh   21    08  2020   Hospitalized
# 24223          Lower Siang  Arunachal Pradesh   21    08  2020   Hospitalized
# 24224        Pakke Kessang  Arunachal Pradesh   21    08  2020   Hospitalized
# 24225          East Kameng  Arunachal Pradesh   21    08  2020      Recovered
# 24226          West Kameng  Arunachal Pradesh   21    08  2020      Recovered
# 24227          Lower Siang  Arunachal Pradesh   21    08  2020      Recovered
# 24228           Papum Pare  Arunachal Pradesh   21    08  2020      Recovered
# 24229                Tirap  Arunachal Pradesh   21    08  2020      Recovered
# 24230  Lower Dibang Valley  Arunachal Pradesh   21    08  2020      Recovered
# 24231          Upper Siang  Arunachal Pradesh   21    08  2020      Recovered
# 24232                  NaN          Meghalaya   21    08  2020   Hospitalized
# 24233     East Khasi Hills          Meghalaya   21    08  2020   Hospitalized
# 24234                  NaN          Meghalaya   21    08  2020      Recovered
# 24235     East Khasi Hills          Meghalaya   21    08  2020      Recovered
# 24236               Raipur       Chhattisgarh   21    08  2020   Hospitalized
# 24237              Raigarh       Chhattisgarh   21    08  2020   Hospitalized
# 24238       Janjgir Champa       Chhattisgarh   21    08  2020   Hospitalized
# 24239             Dhamtari       Chhattisgarh   21    08  2020   Hospitalized
# 24240               Raipur       Chhattisgarh   21    08  2020      Recovered
# 24241                 Durg       Chhattisgarh   21    08  2020      Recovered
# 24242                Balod       Chhattisgarh   21    08  2020      Recovered
# 24243             Bametara       Chhattisgarh   21    08  2020      Recovered
# 24244          Other State       Chhattisgarh   21    08  2020      Recovered
# 24245                  NaN              Assam   21    08  2020      Recovered
# 24246                  NaN                NaN  NaN   NaN   NaN            NaN
#
# [271480 rows x 11 columns]

# %%
df.to_csv('Covid19India.csv')
